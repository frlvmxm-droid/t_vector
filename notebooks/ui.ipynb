# %%
# Ensure repo root is on sys.path so ui_widgets / service modules resolve
import sys, pathlib
_here = pathlib.Path.cwd()
_repo = _here if (_here / 'ui_widgets').is_dir() else _here.parent
if str(_repo) not in sys.path:
    sys.path.insert(0, str(_repo))

# %%
from ui_widgets import build_app
from IPython.display import display
display(build_app())
